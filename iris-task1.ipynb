# %% [markdown]
# # Task1 (Beginner Level): Iris Flowers Classification ML Project

# %% [markdown]
# ## Author : Vaishnavi Jadhav

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="iris-task1")
# Out:
# [jovian] Updating notebook "vaishnavijadhav142002/iris-task1" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/vaishnavijadhav142002/iris-task1
# 'https://jovian.ai/vaishnavijadhav142002/iris-task1'

# %% [markdown]
# ## Importing Libraries

# %%
#importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Read CSV in Dataframe

# %%
#creating dataframe by reading data
df=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')

# %%
df.head(100)
# Out:
#     5.1  3.5  1.4  0.2      Iris-setosa
# 0   4.9  3.0  1.4  0.2      Iris-setosa
# 1   4.7  3.2  1.3  0.2      Iris-setosa
# 2   4.6  3.1  1.5  0.2      Iris-setosa
# 3   5.0  3.6  1.4  0.2      Iris-setosa
# 4   5.4  3.9  1.7  0.4      Iris-setosa
# ..  ...  ...  ...  ...              ...
# 95  5.7  2.9  4.2  1.3  Iris-versicolor
# 96  6.2  2.9  4.3  1.3  Iris-versicolor
# 97  5.1  2.5  3.0  1.1  Iris-versicolor
# 98  5.7  2.8  4.1  1.3  Iris-versicolor
# 99  6.3  3.3  6.0  2.5   Iris-virginica
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Data Preprosessing

# %%
df.columns=['x0','x1','x2','x3','types']

# %%
df.head(25)
# Out:
#      x0   x1   x2   x3        types
# 0   4.9  3.0  1.4  0.2  Iris-setosa
# 1   4.7  3.2  1.3  0.2  Iris-setosa
# 2   4.6  3.1  1.5  0.2  Iris-setosa
# 3   5.0  3.6  1.4  0.2  Iris-setosa
# 4   5.4  3.9  1.7  0.4  Iris-setosa
# 5   4.6  3.4  1.4  0.3  Iris-setosa
# 6   5.0  3.4  1.5  0.2  Iris-setosa
# 7   4.4  2.9  1.4  0.2  Iris-setosa
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa
# 17  5.7  3.8  1.7  0.3  Iris-setosa
# 18  5.1  3.8  1.5  0.3  Iris-setosa
# 19  5.4  3.4  1.7  0.2  Iris-setosa
# 20  5.1  3.7  1.5  0.4  Iris-setosa
# 21  4.6  3.6  1.0  0.2  Iris-setosa
# 22  5.1  3.3  1.7  0.5  Iris-setosa
# 23  4.8  3.4  1.9  0.2  Iris-setosa
# 24  5.0  3.0  1.6  0.2  Iris-setosa

# %%
X=df[['x0','x1','x2','x3']]
Y=df['types']

# %%
X
# Out:
#       x0   x1   x2   x3
# 0    4.9  3.0  1.4  0.2
# 1    4.7  3.2  1.3  0.2
# 2    4.6  3.1  1.5  0.2
# 3    5.0  3.6  1.4  0.2
# 4    5.4  3.9  1.7  0.4
# ..   ...  ...  ...  ...
# 144  6.7  3.0  5.2  2.3
# 145  6.3  2.5  5.0  1.9
# 146  6.5  3.0  5.2  2.0
# 147  6.2  3.4  5.4  2.3
# 148  5.9  3.0  5.1  1.8
#
# [149 rows x 4 columns]

# %%
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 144    Iris-virginica
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# Name: types, Length: 149, dtype: object

# %% [markdown]
# ## Data Visualization

# %%
colors={'Iris-setosa':'orange','Iris-versicolor':'blue','Iris-virginica':'green'}
pd.plotting.scatter_matrix(df,figsize=(15,10),grid=True,c=df['types'].map(colors),s=70)
# Out:
# array([[<AxesSubplot:xlabel='x0', ylabel='x0'>,
#         <AxesSubplot:xlabel='x1', ylabel='x0'>,
#         <AxesSubplot:xlabel='x2', ylabel='x0'>,
#         <AxesSubplot:xlabel='x3', ylabel='x0'>],
#        [<AxesSubplot:xlabel='x0', ylabel='x1'>,
#         <AxesSubplot:xlabel='x1', ylabel='x1'>,
#         <AxesSubplot:xlabel='x2', ylabel='x1'>,
#         <AxesSubplot:xlabel='x3', ylabel='x1'>],
#        [<AxesSubplot:xlabel='x0', ylabel='x2'>,
#         <AxesSubplot:xlabel='x1', ylabel='x2'>,
#         <AxesSubplot:xlabel='x2', ylabel='x2'>,
#         <AxesSubplot:xlabel='x3', ylabel='x2'>],
#        [<AxesSubplot:xlabel='x0', ylabel='x3'>,
#         <AxesSubplot:xlabel='x1', ylabel='x3'>,
#         <AxesSubplot:xlabel='x2', ylabel='x3'>,
#         <AxesSubplot:xlabel='x3', ylabel='x3'>]], dtype=object)

# %% [markdown]
# ## Spliting Data For Training and Testing

# %%
X.shape
# Out:
# (149, 4)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#       x0   x1   x2   x3
# 81   5.8  2.7  3.9  1.2
# 132  6.3  2.8  5.1  1.5
# 142  6.8  3.2  5.9  2.3
# 75   6.8  2.8  4.8  1.4
# 108  7.2  3.6  6.1  2.5
# ..   ...  ...  ...  ...
# 71   6.3  2.5  4.9  1.5
# 106  7.3  2.9  6.3  1.8
# 14   5.7  4.4  1.5  0.4
# 92   5.0  2.3  3.3  1.0
# 102  6.3  2.9  5.6  1.8
#
# [104 rows x 4 columns]

# %%
Y_train
# Out:
# 81     Iris-versicolor
# 132     Iris-virginica
# 142     Iris-virginica
# 75     Iris-versicolor
# 108     Iris-virginica
#             ...
# 71     Iris-versicolor
# 106     Iris-virginica
# 14         Iris-setosa
# 92     Iris-versicolor
# 102     Iris-virginica
# Name: types, Length: 104, dtype: object

# %%
X_test
# Out:
#       x0   x1   x2   x3
# 73   6.4  2.9  4.3  1.3
# 18   5.1  3.8  1.5  0.3
# 117  7.7  2.6  6.9  2.3
# 78   5.7  2.6  3.5  1.0
# 76   6.7  3.0  5.0  1.7
# 31   5.2  4.1  1.5  0.1
# 64   6.7  3.1  4.4  1.4
# 140  6.9  3.1  5.1  2.3
# 68   5.6  2.5  3.9  1.1
# 82   6.0  2.7  5.1  1.6
# 109  6.5  3.2  5.1  2.0
# 12   4.3  3.0  1.1  0.1
# 36   4.9  3.1  1.5  0.1
# 9    5.4  3.7  1.5  0.2
# 19   5.4  3.4  1.7  0.2
# 56   4.9  2.4  3.3  1.0
# 136  6.4  3.1  5.5  1.8
# 69   5.9  3.2  4.8  1.8
# 55   6.3  3.3  4.7  1.6
# 131  6.4  2.8  5.6  2.2
# 29   4.8  3.1  1.6  0.2
# 123  6.7  3.3  5.7  2.1
# 26   5.2  3.5  1.5  0.2
# 127  6.4  2.8  5.6  2.1
# 128  7.2  3.0  5.8  1.6
# 144  6.7  3.0  5.2  2.3
# 110  6.4  2.7  5.3  1.9
# 101  7.1  3.0  5.9  2.1
# 45   5.1  3.8  1.6  0.2
# 30   5.4  3.4  1.5  0.4
# 22   5.1  3.3  1.7  0.5
# 15   5.4  3.9  1.3  0.4
# 65   5.6  3.0  4.5  1.5
# 11   4.8  3.0  1.4  0.1
# 42   5.0  3.5  1.6  0.6
# 105  4.9  2.5  4.5  1.7
# 51   6.9  3.1  4.9  1.5
# ...

# %%
Y_test
# Out:
# 73     Iris-versicolor
# 18         Iris-setosa
# 117     Iris-virginica
# 78     Iris-versicolor
# 76     Iris-versicolor
# 31         Iris-setosa
# 64     Iris-versicolor
# 140     Iris-virginica
# 68     Iris-versicolor
# 82     Iris-versicolor
# 109     Iris-virginica
# 12         Iris-setosa
# 36         Iris-setosa
# 9          Iris-setosa
# 19         Iris-setosa
# 56     Iris-versicolor
# 136     Iris-virginica
# 69     Iris-versicolor
# 55     Iris-versicolor
# 131     Iris-virginica
# 29         Iris-setosa
# 123     Iris-virginica
# 26         Iris-setosa
# 127     Iris-virginica
# 128     Iris-virginica
# 144     Iris-virginica
# 110     Iris-virginica
# 101     Iris-virginica
# 45         Iris-setosa
# 30         Iris-setosa
# 22         Iris-setosa
# 15         Iris-setosa
# 65     Iris-versicolor
# 11         Iris-setosa
# 42         Iris-setosa
# 105     Iris-virginica
# 51     Iris-versicolor
# 27         Iris-setosa
# 4          Iris-setosa
# 32         Iris-setosa
# ...

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((104, 4), (45, 4), (104,), (45,))

# %%
#logistic regression

model_kn=KNeighborsClassifier(9)
model_kn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
print('Train Data : - ',model_kn.score(X_train,Y_train),'\nTest Data : - ',model_kn.score(X_test,Y_test))
# Out:
# Train Data : -  0.9903846153846154
# Test Data : -  0.9111111111111111
# /opt/conda/lib/python3.9/site-packages/sklearn/base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/sklearn/base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
jovian.commit(project="iris-task1")
